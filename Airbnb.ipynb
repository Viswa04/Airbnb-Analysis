# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.4/305.4 kB 22.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pymongo.server_api import ServerApi
import urllib
import ssl

# %%
# MongoDB Connect

username = "kviswa004"
password = "Viswa@04"
# password
# Encode the username and password

encoded_username = urllib.parse.quote_plus(username)
encoded_password = urllib.parse.quote_plus(password)


# Construct the URI with encoded credentials


uri = f"mongodb+srv://{encoded_username}:{encoded_password}@cluster0.omqgkpo.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"


# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'), tz_aware=False, connect=True)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# DB Connect
db = client["sample_airbnb"]
collection = db["listingsAndReviews"]

# %%
col_data = []
for i in collection.find():
    data = dict(_id = i["_id"],
                Listing_URL = i["listing_url"],
                Name = i.get("name"),
                Property_Type = i["property_type"],
                Room_Type = i["room_type"],
                Bed_Type = i["bed_type"],
                Min_Nights = int(i["minimum_nights"]),
                Max_nights = int(i["maximum_nights"]),
                Cancellation_Policy = i["cancellation_policy"],
                Accommodates = i["accommodates"],
                Bedrooms = i.get("bedrooms"),
                Beds = i.get("beds"),
                No_of_reviews = i['number_of_reviews'],
                Bathrooms = i.get('bathrooms'),
                Price = i['price'],
                Extra_People = i['extra_people'],
                Guests_Included = i['guests_included'],
                Images = i['images'].get('picture_url'),
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Cleaning_Fee = i.get("cleaning_fee"))
    col_data.append(data)

# %%
df = pd.DataFrame(col_data)

# %%
df.head()
# Out:
#         _id                            Listing_URL  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                Name Property_Type        Room_Type  Bed_Type  \
# 0           Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1      Horto flat with small garden     Apartment  Entire home/apt  Real Bed
# 2  Ocean View Waikiki Marina w/prkg   Condominium  Entire home/apt  Real Bed
# 3          Private Room in Bushwick     Apartment     Private room  Real Bed
# 4       Apt Linda Vista Lagoa - Rio     Apartment     Private room  Real Bed
#
#    Min_Nights  Max_nights          Cancellation_Policy  Accommodates  \
# 0           2          30                     moderate             8
# ...

# %%
df.shape
# Out:
# (5555, 20)

# %%
df.describe()
# Out:
#         Min_Nights    Max_nights  Accommodates     Bedrooms         Beds  \
# count  5555.000000  5.555000e+03   5555.000000  5550.000000  5542.000000
# mean      5.564356  1.382776e+06      3.505851     1.411712     2.071454
# std      22.613861  5.256920e+07      2.297019     1.041942     1.619660
# min       1.000000  1.000000e+00      1.000000     0.000000     0.000000
# 25%       1.000000  5.900000e+01      2.000000     1.000000     1.000000
# 50%       2.000000  1.125000e+03      3.000000     1.000000     2.000000
# 75%       3.000000  1.125000e+03      4.000000     2.000000     3.000000
# max    1250.000000  2.147484e+09     16.000000    20.000000    25.000000
#
#        No_of_reviews  Review_scores
# count    5555.000000    4081.000000
# mean       27.606481      93.099240
# std        49.798376       9.023483
# min         0.000000      20.000000
# 25%         1.000000      90.000000
# 50%         5.000000      95.000000
# 75%        32.000000      99.000000
# ...

# %% [markdown]
# # ***Handling Null Values***

# %%
df.isnull().sum()
# Out:
# _id                       0
# Listing_URL               0
# Name                      0
# Property_Type             0
# Room_Type                 0
# Bed_Type                  0
# Min_Nights                0
# Max_nights                0
# Cancellation_Policy       0
# Accommodates              0
# Bedrooms                  5
# Beds                     13
# No_of_reviews             0
# Bathrooms                10
# Price                     0
# Extra_People              0
# Guests_Included           0
# Images                    0
# Review_scores          1474
# Cleaning_Fee           1531
# dtype: int64

# %%
df["Bedrooms"].fillna(0, inplace=True)
df["Beds"].fillna(0, inplace=True)
df["Bathrooms"].fillna(0, inplace=True)
df["Review_scores"].fillna(0, inplace=True)
df["Cleaning_Fee"].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# _id                    0
# Listing_URL            0
# Name                   0
# Property_Type          0
# Room_Type              0
# Bed_Type               0
# Min_Nights             0
# Max_nights             0
# Cancellation_Policy    0
# Accommodates           0
# Bedrooms               0
# Beds                   0
# No_of_reviews          0
# Bathrooms              0
# Price                  0
# Extra_People           0
# Guests_Included        0
# Images                 0
# Review_scores          0
# Cleaning_Fee           0
# dtype: int64

# %% [markdown]
# # ***Handling Datatypes***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5555 non-null   object
#  1   Listing_URL          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Property_Type        5555 non-null   object
#  4   Room_Type            5555 non-null   object
#  5   Bed_Type             5555 non-null   object
#  6   Min_Nights           5555 non-null   int64
#  7   Max_nights           5555 non-null   int64
#  8   Cancellation_Policy  5555 non-null   object
#  9   Accommodates         5555 non-null   int64
#  10  Bedrooms             5555 non-null   float64
#  11  Beds                 5555 non-null   float64
#  12  No_of_reviews        5555 non-null   int64
#  13  Bathrooms            5555 non-null   object
#  14  Price                5555 non-null   object
# ...

# %%
df["Price"] = df["Price"].astype(str).astype(float).astype(int)
df["Extra_People"] = df["Extra_People"].astype(str).astype(float).astype(int)
df["Guests_Included"] = df["Guests_Included"].astype(str).astype(float).astype(int)
df["Cleaning_Fee"] = df["Cleaning_Fee"].astype(str).astype(float).astype(int)

# %%
df.dtypes
# Out:
# _id                     object
# Listing_URL             object
# Name                    object
# Property_Type           object
# Room_Type               object
# Bed_Type                object
# Min_Nights               int64
# Max_nights               int64
# Cancellation_Policy     object
# Accommodates             int64
# Bedrooms               float64
# Beds                   float64
# No_of_reviews            int64
# Bathrooms               object
# Price                    int64
# Extra_People             int64
# Guests_Included          int64
# Images                  object
# Review_scores          float64
# Cleaning_Fee             int64
# dtype: object

# %% [markdown]
# # ***Collecting the Host Details***

# %%
host = []
for i in collection.find({}, {"_id":1, "host":1}):
  host.append(i)

# %%
df_1 = pd.DataFrame(host)

# %%
df_1
# Out:
#            _id                                               host
# 0     10006546  {'host_id': '51399391', 'host_url': 'https://w...
# 1     10009999  {'host_id': '1282196', 'host_url': 'https://ww...
# 2      1001265  {'host_id': '5448114', 'host_url': 'https://ww...
# 3     10021707  {'host_id': '11275734', 'host_url': 'https://w...
# 4     10030955  {'host_id': '51496939', 'host_url': 'https://w...
# ...        ...                                                ...
# 5550   9983221  {'host_id': '37776205', 'host_url': 'https://w...
# 5551   9985696  {'host_id': '51303748', 'host_url': 'https://w...
# 5552   9987200  {'host_id': '51314789', 'host_url': 'https://w...
# 5553   9990304  {'host_id': '51013381', 'host_url': 'https://w...
# 5554   9993190  {'host_id': '51013381', 'host_url': 'https://w...
#
# [5555 rows x 2 columns]

# %%
host_col = {"_id":[], "host_id":[], "host_url":[], "host_name":[], "host_location":[], "host_response_time":[], "host_thumbnail_url":[], "host_picture_url":[], "host_neighbourhood":[],
            "host_response_rate":[], "host_is_superhost":[], "host_has_profile_pic":[], "host_identity_verified":[], "host_listings_count":[], "host_total_listings_count":[], "host_verifications":[]}

for i in df_1["_id"]:
  host_col["_id"].append(i)

for i in df_1["host"]:
  host_col["host_id"].append(i["host_id"])
  host_col["host_url"].append(i["host_url"])
  host_col["host_name"].append(i["host_name"])
  host_col["host_location"].append(i["host_location"])
  host_col["host_response_time"].append(i.get("host_response_time"))
  host_col["host_thumbnail_url"].append(i["host_thumbnail_url"])
  host_col["host_picture_url"].append(i["host_picture_url"])
  host_col["host_neighbourhood"].append(i["host_neighbourhood"])
  host_col["host_response_rate"].append(i.get("host_response_rate"))
  host_col["host_is_superhost"].append(i["host_is_superhost"])
  host_col["host_has_profile_pic"].append(i["host_has_profile_pic"])
  host_col["host_identity_verified"].append(i["host_identity_verified"])
  host_col["host_listings_count"].append(i["host_listings_count"])
  host_col["host_total_listings_count"].append(i["host_total_listings_count"])
  host_col["host_verifications"].append(i["host_verifications"])

# %%
df_host = pd.DataFrame(host_col)

# %%
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 1  10009999   1282196   https://www.airbnb.com/users/show/1282196
# 2   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 3  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 4  10030955  51496939  https://www.airbnb.com/users/show/51496939
#
#      host_name                                    host_location  \
# 0  Ana&Gonçalo                  Porto, Porto District, Portugal
# 1        Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2        David                  Honolulu, Hawaii, United States
# 3         Josh                New York, New York, United States
# 4        Livia                                               BR
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# ...

# %% [markdown]
# # ***Handling Null Values***

# %%
df_host.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
df_host["host_response_time"].fillna("Not Specified", inplace=True)
df_host["host_response_rate"].fillna("Not Specified", inplace=True)
df_host["host_neighbourhood"] = df_host["host_neighbourhood"].replace({"": "Not Specified"})

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host.head(10)
# Out:
#         _id   host_id                                    host_url  \
# 0  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 1  10009999   1282196   https://www.airbnb.com/users/show/1282196
# 2   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 3  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 4  10030955  51496939  https://www.airbnb.com/users/show/51496939
# 5   1003530    454250    https://www.airbnb.com/users/show/454250
# 6  10038496  51530266  https://www.airbnb.com/users/show/51530266
# 7  10047964   1241644   https://www.airbnb.com/users/show/1241644
# 8  10051164  51326285  https://www.airbnb.com/users/show/51326285
# 9  10057447  51612949  https://www.airbnb.com/users/show/51612949
#
#      host_name                                    host_location  \
# 0  Ana&Gonçalo                  Porto, Porto District, Portugal
# 1        Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# ...

# %%
# Changing True or False values
df_host["host_is_superhost"] = df_host["host_is_superhost"].replace({True:"Yes", False:"No"})
df_host["host_has_profile_pic"] = df_host["host_has_profile_pic"].replace({True:"Yes", False:"No"})
df_host["host_identity_verified"] = df_host["host_identity_verified"].replace({True:"Yes", False:"No"})

# %%
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0  10006546  51399391  https://www.airbnb.com/users/show/51399391
# 1  10009999   1282196   https://www.airbnb.com/users/show/1282196
# 2   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 3  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 4  10030955  51496939  https://www.airbnb.com/users/show/51496939
#
#      host_name                                    host_location  \
# 0  Ana&Gonçalo                  Porto, Porto District, Portugal
# 1        Ynaie  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2        David                  Honolulu, Hawaii, United States
# 3         Josh                New York, New York, United States
# 4        Livia                                               BR
#
#   host_response_time                                 host_thumbnail_url  \
# 0     within an hour  https://a0.muscache.com/im/pictures/fab79f25-2...
# ...

# %% [markdown]
# # ***Collecting the Address Details***

# %%
address = []
for i in collection.find({}, {"_id":1, "address":1}):
  address.append(i)

# %%
df_2 = pd.DataFrame(address)

# %%
df_2
# Out:
#            _id                                            address
# 0     10006546  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1     10009999  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 2      1001265  {'street': 'Honolulu, HI, United States', 'sub...
# 3     10021707  {'street': 'Brooklyn, NY, United States', 'sub...
# 4     10030955  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# ...        ...                                                ...
# 5550   9983221  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5551   9985696  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 5552   9987200  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5553   9990304  {'street': 'Lahaina, HI, United States', 'subu...
# 5554   9993190  {'street': 'Lahaina, HI, United States', 'subu...
#
# [5555 rows x 2 columns]

# %%
address_col = {"_id":[], "street":[], "suburb":[], "government_area":[], "market":[], "country":[], "country_code":[], "location_type":[], "longitude":[],
               "latitude":[], "is_location_exact":[]}

for i in df_2["_id"]:
  address_col["_id"].append(i)

for i in df_2["address"]:
  address_col["street"].append(i["street"])
  address_col["suburb"].append(i["suburb"])
  address_col["government_area"].append(i["government_area"])
  address_col["market"].append(i["market"])
  address_col["country"].append(i["country"])
  address_col["country_code"].append(i["country_code"])
  address_col["location_type"].append(i["location"]["type"])
  address_col["longitude"].append(i["location"]["coordinates"][0])
  address_col["latitude"].append(i["location"]["coordinates"][1])
  address_col["is_location_exact"].append(i["location"]["is_location_exact"])

# %%
df_address = pd.DataFrame(address_col)

# %%
df_address.head()
# Out:
#         _id                                  street           suburb  \
# 0  10006546                  Porto, Porto, Portugal
# 1  10009999  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2   1001265             Honolulu, HI, United States            Oʻahu
# 3  10021707             Brooklyn, NY, United States         Brooklyn
# 4  10030955  Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
#
#                                      government_area          market  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 1                                    Jardim Botânico  Rio De Janeiro
# 2                               Primary Urban Center            Oahu
# 3                                           Bushwick        New York
# 4                                              Lagoa  Rio De Janeiro
#
#          country country_code location_type   longitude   latitude  \
# 0       Portugal           PT         Point   -8.613080  41.141300
# ...

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %% [markdown]
# # ***Handling Empty Values and Boolean Values***

# %%
df_address["suburb"] = df_address["suburb"].replace({'': "Not Specified"})
df_address["market"] = df_address["market"].replace({'': "Not Specified"})

df_address["is_location_exact"] = df_address["is_location_exact"].replace({True: "Yes", False: "No"})

# %%
df_address.head()
# Out:
#         _id                                  street           suburb  \
# 0  10006546                  Porto, Porto, Portugal    Not Specified
# 1  10009999  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2   1001265             Honolulu, HI, United States            Oʻahu
# 3  10021707             Brooklyn, NY, United States         Brooklyn
# 4  10030955  Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
#
#                                      government_area          market  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 1                                    Jardim Botânico  Rio De Janeiro
# 2                               Primary Urban Center            Oahu
# 3                                           Bushwick        New York
# 4                                              Lagoa  Rio De Janeiro
#
#          country country_code location_type   longitude   latitude  \
# ...

# %% [markdown]
# # ***Collecting the Availability***

# %%
availability = []
for i in collection.find({}, {"_id":1, "availability":1}):
  availability.append(i)

# %%
df_3 = pd.DataFrame(availability)

# %%
df_3
# Out:
#            _id                                       availability
# 0     10006546  {'availability_30': 28, 'availability_60': 47,...
# 1     10009999  {'availability_30': 0, 'availability_60': 0, '...
# 2      1001265  {'availability_30': 16, 'availability_60': 46,...
# 3     10021707  {'availability_30': 0, 'availability_60': 0, '...
# 4     10030955  {'availability_30': 28, 'availability_60': 58,...
# ...        ...                                                ...
# 5550   9983221  {'availability_30': 26, 'availability_60': 51,...
# 5551   9985696  {'availability_30': 30, 'availability_60': 60,...
# 5552   9987200  {'availability_30': 7, 'availability_60': 29, ...
# 5553   9990304  {'availability_30': 8, 'availability_60': 20, ...
# 5554   9993190  {'availability_30': 0, 'availability_60': 8, '...
#
# [5555 rows x 2 columns]

# %%
availability_col = {"_id":[], "availability_30":[], "availability_60":[], "availability_90":[], "availability_365":[]}

for i in df_3["_id"]:
  availability_col["_id"].append(i)

for i in df_3["availability"]:
  availability_col["availability_30"].append(i["availability_30"])
  availability_col["availability_60"].append(i["availability_60"])
  availability_col["availability_90"].append(i["availability_90"])
  availability_col["availability_365"].append(i["availability_365"])

# %%
df_availability = pd.DataFrame(availability_col)

# %%
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0  10006546               28               47               74
# 1  10009999                0                0                0
# 2   1001265               16               46               76
# 3  10021707                0                0                0
# 4  10030955               28               58               88
#
#    availability_365
# 0               239
# 1                 0
# 2               343
# 3                 0
# 4               363

# %%
df_availability.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %% [markdown]
# # ***Collecting the Amenities Details***

# %%
amenities = []
for i in collection.find({}, {"_id":1, "amenities":1}):
  amenities.append(i)

# %%
df_amenities = pd.DataFrame(amenities)

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0     10006546  [TV, Cable TV, Wifi, Kitchen, Paid parking off...
# 1     10009999  [Wifi, Wheelchair accessible, Kitchen, Free pa...
# 2      1001265  [TV, Cable TV, Wifi, Air conditioning, Pool, K...
# 3     10021707  [Internet, Wifi, Air conditioning, Kitchen, Bu...
# 4     10030955  [TV, Cable TV, Internet, Wifi, Air conditionin...
# ...        ...                                                ...
# 5550   9983221  [TV, Cable TV, Internet, Wifi, Kitchen, Paid p...
# 5551   9985696  [TV, Cable TV, Internet, Wifi, Kitchen, Buzzer...
# 5552   9987200  [TV, Cable TV, Wifi, Air conditioning, Pool, G...
# 5553   9990304  [TV, Cable TV, Wifi, Air conditioning, Wheelch...
# 5554   9993190  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...
#
# [5555 rows x 2 columns]

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        5555 non-null   object
#  1   amenities  5555 non-null   object
# dtypes: object(2)
# memory usage: 86.9+ KB

# %% [markdown]
# # ***Merging all DataFrames***

# %%
Airbnb_df = pd.merge(df, df_host, on="_id")
Airbnb_df = pd.merge(Airbnb_df, df_address, on="_id")
Airbnb_df = pd.merge(Airbnb_df, df_availability, on="_id")
Airbnb_df = pd.merge(Airbnb_df, df_amenities, on="_id")

# %%
Airbnb_df
# Out:
#            _id                            Listing_URL  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name Property_Type  \
# 0                               Ribeira Charming Duplex         House
# 1                          Horto flat with small garden     Apartment
# 2                      Ocean View Waikiki Marina w/prkg   Condominium
# ...

# %%
# Saving the file
Airbnb_df.to_csv("Airbnb.csv", index=False)

# %%
df_airbnb = pd.read_csv("/content/Airbnb.csv")

# %%
df_airbnb.head()
# Out:
#         _id                            Listing_URL  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                Name Property_Type        Room_Type  Bed_Type  \
# 0           Ribeira Charming Duplex         House  Entire home/apt  Real Bed
# 1      Horto flat with small garden     Apartment  Entire home/apt  Real Bed
# 2  Ocean View Waikiki Marina w/prkg   Condominium  Entire home/apt  Real Bed
# 3          Private Room in Bushwick     Apartment     Private room  Real Bed
# 4       Apt Linda Vista Lagoa - Rio     Apartment     Private room  Real Bed
#
#    Min_Nights  Max_nights          Cancellation_Policy  Accommodates  \
# 0           2          30                     moderate             8
# ...
